# %%
import pandas as pd

# Lee el archivo CSV
encuesta_df = pd.read_csv('encuesta_procesada.csv')

# %%
encuesta_df
# Out:
#                      Marca temporal  \
# 0    2024/05/01 4:53:50 p. m. GMT-5
# 1    2024/05/01 4:54:51 p. m. GMT-5
# 2    2024/05/01 4:56:25 p. m. GMT-5
# 3    2024/05/01 5:00:05 p. m. GMT-5
# 4    2024/05/01 5:00:08 p. m. GMT-5
# ..                              ...
# 498  2024/05/01 9:56:40 p. m. GMT-5
# 499  2024/05/01 9:20:32 p. m. GMT-5
# 500  2024/05/06 9:45:56 a. m. GMT-5
# 501  2024/05/01 7:33:26 p. m. GMT-5
# 502  2024/05/01 9:13:37 p. m. GMT-5
#
#     1.- Datos demográficos del cliente\n¿Qué edad tiene?: 2.- Género:  \
# 0                                         25 a 35 años       Femenino
# 1                                         25 a 35 años      Masculino
# 2                                         35 a 44 años       Femenino
# 3                                         45 a 54 años      Masculino
# 4                                         45 a 54 años       Femenino
# ..                                                 ...            ...
# 498                                       25 a 35 años      Masculino
# 499                                       25 a 35 años      Masculino
# 500                                       35 a 44 años      Masculino
# 501                                       35 a 44 años      Masculino
# 502                                       55 a 64 años      Masculino
#
#     3.- ¿Qué nivel educativo tiene? 4.- ¿Cuántos miembros compone su familia?  \
# 0                     Universitario                              1-3 miembros
# 1                          Posgrado                              4-6 miembros
# 2                     Universitario                              4-6 miembros
# 3                     Universitario                              1-3 miembros
# 4                           Técnico                              4-6 miembros
# ..                              ...                                       ...
# 498                   Universitario                          7 o más miembros
# 499                        Posgrado                              1-3 miembros
# 500                         Técnico                              1-3 miembros
# 501                   Universitario                              4-6 miembros
# 502                        Posgrado                          7 o más miembros
#
#     5.- ¿Con qué frecuencia conduce?  \
# 0                        Diariamente
# 1                        Diariamente
# 2                              Nunca
# 3                Una vez a la semana
# 4                Una vez a la semana
# ..                               ...
# 498         Varias veces a la semana
# 499         Varias veces a la semana
# 500                      Diariamente
# 501         Varias veces a la semana
# 502     Menos de una vez a la semana
#
#     6.- ¿Qué tipo de carreteras utiliza con más frecuencia?  \
# 0                                           Autopistas
# 1                                       Calles urbanas
# 2                                                  Bus
# 3                                       Calles urbanas
# 4                                      Caminos rurales
# ..                                                 ...
# 498                                                Bus
# 499                                     Calles urbanas
# 500                                                Bus
# 501                                     Calles urbanas
# 502                                     Calles urbanas
#
#     7.- ¿Con qué frecuencia conduce por la noche?  \
# 0                                           Nunca
# 1                                     Diariamente
# 2                                           Nunca
# 3                                           Nunca
# 4                                     Diariamente
# ..                                            ...
# 498                                Ocasionalmente
# 499                                Ocasionalmente
# 500                                Ocasionalmente
# 501                                Ocasionalmente
# 502                                Ocasionalmente
#
#     8.- ¿Qué tan preocupado está por la seguridad de sus vehículos y activos?  \
# 0                                           Preocupado
# 1                                              Neutral
# 2                                              Neutral
# 3                                           Preocupado
# 4                                              Neutral
# ..                                                 ...
# 498                                         Preocupado
# 499                                         Preocupado
# 500                                            Neutral
# 501                                         Preocupado
# 502                                         Preocupado
#
#     9.- ¿Ha sido víctima de algún robo o hurto en los últimos 5 años?  ...  \
# 0                                                   No                 ...
# 1                                                   No                 ...
# 2                                                   No                 ...
# 3                                                   No                 ...
# 4                                                   No                 ...
# ..                                                 ...                 ...
# 498                                                 No                 ...
# 499                                                 No                 ...
# 500                                                 Si                 ...
# 501                                                 Si                 ...
# 502                                                 No                 ...
#
#     14.- ¿Cómo Ud se enteró que existe el servicio de rastreo satelital?  \
# 0    Publicidad en redes sociales o plataformas dig...
# 1                 Recomendación de un amigo o familiar
# 2                 Recomendación de un amigo o familiar
# 3    Publicidad en redes sociales o plataformas dig...
# 4                 Recomendación de un amigo o familiar
# ..                                                 ...
# 498  Publicidad en redes sociales o plataformas dig...
# 499                               Precisión de rastreo
# 500  Publicidad en redes sociales o plataformas dig...
# 501               Recomendación de un amigo o familiar
# 502               Recomendación de un amigo o familiar
#
#     15.- ¿Qué otras soluciones de seguridad utiliza en su vehículo?  \
# 0                                              Ninguna
# 1                                   Sistemas de alarma
# 2                                   Sistemas de alarma
# 3                                   Sistemas de alarma
# 4                                   Sistemas de alarma
# ..                                                 ...
# 498  Control de acceso automático y remoto;GPS inal...
# 499                                 Sistemas de alarma
# 500                                            Ninguna
# 501                      GPS inalámbrico independiente
# 502                               Cámaras de seguridad
#
#     16.- ¿Qué considera Ud. que necesita una aplicación móvil para rastrear vehículos y activos?  \
# 0                         GPS Tracker – Video tracking
# 1                         GPS Tracker – Video tracking
# 2                                       Imágenes en 3D
# 3                         GPS Tracker – Video tracking
# 4                   Compartir ubicación en tiempo real
# ..                                                 ...
# 498                 Compartir ubicación en tiempo real
# 499                       GPS Tracker – Video tracking
# 500                       GPS Tracker – Video tracking
# 501                                     Imágenes en 3D
# 502                 Compartir ubicación en tiempo real
#
#     17.- ¿Qué tipo de beneficios busca al utilizar un servicio de rastreo satelital?  \
# 0                             Monitoreo en tiempo real
# 1    Protección de sus vehículos;Monitoreo en tiemp...
# 2                          Protección de sus vehículos
# 3                          Protección de sus vehículos
# 4                             Monitoreo en tiempo real
# ..                                                 ...
# 498       Monitoreo en tiempo real;Informes detallados
# 499  Protección de sus vehículos;Monitoreo en tiemp...
# 500  Protección de sus vehículos;Monitoreo en tiemp...
# 501                        Protección de sus vehículos
# 502                           Monitoreo en tiempo real
#
#     18.- ¿Ha recibido alguna vez alertas de seguridad o emergencias relacionadas con su ubicación?  \
# 0                                                   No
# 1                                                   No
# 2                                                   No
# 3                                                   No
# 4                                                   Si
# ..                                                 ...
# 498                                                 Si
# 499                                                 Si
# 500                                                 No
# 501                                                 Si
# 502                                                 No
#
#     19.- ¿Conoce Ud. el proceso para adquirir un servicio de rastreo satelital?  \
# 0                                                   Si
# 1                                                   No
# 2                                                   Si
# 3                                                   Si
# 4                                                   No
# ..                                                 ...
# 498                                                 No
# 499                                                 Si
# 500                                                 No
# 501                                                 Si
# 502                                                 No
#
#     20.- ¿Prefiere comprar el rastreo satelital en efectivo o a crédito?  \
# 0                                              Crédito
# 1                                              Crédito
# 2                                             Efectivo
# 3                                             Efectivo
# 4                                              Crédito
# ..                                                 ...
# 498                                           Efectivo
# 499                                            Crédito
# 500                                           Efectivo
# 501                                            Crédito
# 502                                           Efectivo
#
#     21.- ¿Ha tenido alguna vez problemas con el robo o la pérdida de sus vehículos?  \
# 0                                                   Si
# 1                                                   No
# 2                                                   No
# 3                                                   No
# 4                                                   No
# ..                                                 ...
# 498                                                 No
# 499                                                 No
# 500                                                 No
# 501                                                 No
# 502                                                 No
#
#     22.- ¿Qué tan importante es para usted tener acceso a la información en tiempo real sobre la ubicación de sus vehículos o activos?  \
# 0                                        Importartante
# 1                                        Importartante
# 2                                        Importartante
# 3                                        Importartante
# 4                                        Importartante
# ..                                                 ...
# 498                                      Importartante
# 499                                      Importartante
# 500                                      Importartante
# 501                                      Importartante
# 502                                      Importartante
#
#     23.- ¿Qué empresas de rastreo satelital conoce?
# 0                                       Rastreo 365
# 1                                        Rastreo365
# 2                                            Hunter
# 3                                       Rastreo 365
# 4                                       No conozco
# ..                                              ...
# 498                                        Ninguna
# 499                                       Chevystar
# 500                                        Ninguna
# 501                                          Hunter
# 502                                         Ninguna
#
# [503 rows x 24 columns]

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
# Paso 2: Seleccionar y renombrar las columnas relevantes
selected_columns = [
    '1.- Datos demográficos del cliente\n¿Qué edad tiene?:',
    '2.- Género:',
    '3.- ¿Qué nivel educativo tiene?',
    '4.- ¿Cuántos miembros compone su familia?',
    '8.- ¿Qué tan preocupado está por la seguridad de sus vehículos y activos?',
    '9.- ¿Ha sido víctima de algún robo o hurto en los últimos 5 años?',
    '10.- ¿Qué le motiva a comprar un servicio de rastreo satelital?',
    '20.- ¿Prefiere comprar el rastreo satelital en efectivo o a crédito?', 
]

filtered_df = encuesta_df[selected_columns]
filtered_df.columns = [
    'Edad',
    'Genero',
    'Nivel_Educativo',
    'Miembros_Familia',
    'Preocupacion por bienes',
    'Victima de Robo',
    'Motivacion para comprar rastreo',
    'Manera de compra',
]

# %%
filtered_df
# Out:
#              Edad     Genero Nivel_Educativo  Miembros_Familia  \
# 0    25 a 35 años   Femenino   Universitario      1-3 miembros
# 1    25 a 35 años  Masculino        Posgrado      4-6 miembros
# 2    35 a 44 años   Femenino   Universitario      4-6 miembros
# 3    45 a 54 años  Masculino   Universitario      1-3 miembros
# 4    45 a 54 años   Femenino         Técnico      4-6 miembros
# ..            ...        ...             ...               ...
# 498  25 a 35 años  Masculino   Universitario  7 o más miembros
# 499  25 a 35 años  Masculino        Posgrado      1-3 miembros
# 500  35 a 44 años  Masculino         Técnico      1-3 miembros
# 501  35 a 44 años  Masculino   Universitario      4-6 miembros
# 502  55 a 64 años  Masculino        Posgrado  7 o más miembros
#
#     Preocupacion por bienes Victima de Robo Motivacion para comprar rastreo  \
# 0                Preocupado              No                    Tranquilidad
# 1                   Neutral              No                       Seguridad
# 2                   Neutral              No                       Seguridad
# 3                Preocupado              No                       Seguridad
# 4                   Neutral              No                       Seguridad
# ..                      ...             ...                             ...
# 498              Preocupado              No  Seguridad;Tranquilidad;Control
# 499              Preocupado              No                       Seguridad
# 500                 Neutral              Si                       Seguridad
# 501              Preocupado              Si                         Control
# 502              Preocupado              No                       Seguridad
#
#     Manera de compra
# 0            Crédito
# 1            Crédito
# 2           Efectivo
# 3           Efectivo
# 4            Crédito
# ..               ...
# 498         Efectivo
# 499          Crédito
# 500         Efectivo
# 501          Crédito
# 502         Efectivo
#
# [503 rows x 8 columns]

# %%
# Paso 3: Codificar las variables categóricas
label_encoders = {}
for column in filtered_df.columns:
    le = LabelEncoder()
    filtered_df.loc[:, column] = le.fit_transform(filtered_df[column])
    label_encoders[column] = le

# %%
filtered_df
# Out:
#     Edad Genero Nivel_Educativo Miembros_Familia Preocupacion por bienes  \
# 0      0      0               5                0                       2
# 1      0      1               2                1                       1
# 2      1      0               5                1                       1
# 3      2      1               5                0                       2
# 4      2      0               4                1                       1
# ..   ...    ...             ...              ...                     ...
# 498    0      1               5                2                       2
# 499    0      1               2                0                       2
# 500    1      1               4                0                       1
# 501    1      1               5                1                       2
# 502    3      1               2                2                       2
#
#     Victima de Robo Motivacion para comprar rastreo Manera de compra
# 0                 0                              15                0
# 1                 0                               7                0
# 2                 0                               7                1
# 3                 0                               7                1
# 4                 0                               7                0
# ..              ...                             ...              ...
# 498               0                              11                1
# 499               0                               7                0
# 500               1                               7                1
# 501               1                               0                0
# 502               0                               7                1
#
# [503 rows x 8 columns]

# %%
# Paso 4: Normalizar los datos
scaler = StandardScaler()
normalized_data = scaler.fit_transform(filtered_df)

# %%
normalized_data
# Out:
# array([[-1.42373759, -1.22575999,  1.14736373, ..., -0.73043589,
#          2.09633359, -0.71555022],
#        [-1.42373759,  0.81582039, -0.95126884, ..., -0.73043589,
#         -0.11484501, -0.71555022],
#        [-0.27607732, -1.22575999,  1.14736373, ..., -0.73043589,
#         -0.11484501,  1.01484286],
#        ...,
#        [-0.27607732,  0.81582039,  0.44781954, ...,  1.36904555,
#         -0.11484501,  1.01484286],
#        [-0.27607732,  0.81582039,  1.14736373, ...,  1.36904555,
#         -2.04962629, -0.71555022],
#        [ 2.01924321,  0.81582039, -0.95126884, ..., -0.73043589,
#         -0.11484501,  1.01484286]])

# %%
# Paso 5: Determinar el número óptimo de clusters usando el método del codo
wcss = []
max_clusters = 10
for i in range(1, max_clusters + 1):
    kmeans = KMeans(n_clusters=i, random_state=42, n_init=10)
    kmeans.fit(normalized_data)
    wcss.append(kmeans.inertia_)

# %%
# Graficar el método del codo
plt.figure(figsize=(10, 6))
plt.plot(range(1, max_clusters + 1), wcss, marker='o', linestyle='-')
plt.title('Elbow Method for Optimal Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.xticks(range(1, max_clusters + 1))
plt.grid(True)
plt.show()

# %%
# Paso 6: Aplicar KMeans con el número óptimo de clusters
optimal_clusters = 4
kmeans = KMeans(n_clusters=optimal_clusters, random_state=42, n_init=10)
clusters = kmeans.fit_predict(normalized_data)

# Agregar las etiquetas de los clusters al dataframe original usando .loc
filtered_df = filtered_df.copy()
filtered_df.loc[:, 'Cluster'] = clusters

# %%
filtered_df
# Out:
#     Edad Genero Nivel_Educativo Miembros_Familia Preocupacion por bienes  \
# 0      0      0               5                0                       2
# 1      0      1               2                1                       1
# 2      1      0               5                1                       1
# 3      2      1               5                0                       2
# 4      2      0               4                1                       1
# ..   ...    ...             ...              ...                     ...
# 498    0      1               5                2                       2
# 499    0      1               2                0                       2
# 500    1      1               4                0                       1
# 501    1      1               5                1                       2
# 502    3      1               2                2                       2
#
#     Victima de Robo Motivacion para comprar rastreo Manera de compra  Cluster
# 0                 0                              15                0        2
# 1                 0                               7                0        0
# 2                 0                               7                1        0
# 3                 0                               7                1        1
# 4                 0                               7                0        0
# ..              ...                             ...              ...      ...
# 498               0                              11                1        1
# 499               0                               7                0        1
# 500               1                               7                1        0
# 501               1                               0                0        3
# 502               0                               7                1        1
#
# [503 rows x 9 columns]

# %%
# Paso 7: Reducir la dimensionalidad a 2D usando PCA
pca = PCA(n_components=2)
pca_components = pca.fit_transform(normalized_data)

# %%
# Paso 8: Graficar los clusters
plt.figure(figsize=(10, 6))
scatter = plt.scatter(pca_components[:, 0], pca_components[:, 1], c=clusters, cmap='viridis')
plt.title('Clusters Visualized using PCA')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar(scatter, label='Cluster')
plt.grid(True)
plt.show()

# Mostrar las primeras filas con las etiquetas de los clusters
print(filtered_df.head())
# Out:
#   Edad Genero Nivel_Educativo Miembros_Familia Preocupacion por bienes  \
# 0    0      0               5                0                       2
# 1    0      1               2                1                       1
# 2    1      0               5                1                       1
# 3    2      1               5                0                       2
# 4    2      0               4                1                       1
#
#   Victima de Robo Motivacion para comprar rastreo Manera de compra  Cluster
# 0               0                              15                0        2
# 1               0                               7                0        0
# 2               0                               7                1        0
# 3               0                               7                1        1
# 4               0                               7                0        0

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

# Realizar el clustering jerárquico
linked = linkage(normalized_data, 'ward')

# Graficar el dendrograma
plt.figure(figsize=(10, 6))
dendrogram(linked, orientation='top', distance_sort='descending', show_leaf_counts=True)
plt.title('Dendrogram for Hierarchical Clustering')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()

# %%
from sklearn.metrics import silhouette_samples, silhouette_score
import numpy as np

# Calcular los coeficientes de silueta para cada punto
silhouette_vals = silhouette_samples(normalized_data, clusters)

# Graficar el gráfico de silueta
plt.figure(figsize=(10, 6))
y_lower, y_upper = 0, 0
for i in range(optimal_clusters):
    cluster_silhouette_vals = silhouette_vals[clusters == i]
    cluster_silhouette_vals.sort()
    y_upper += len(cluster_silhouette_vals)
    plt.fill_betweenx(np.arange(y_lower, y_upper), 0, cluster_silhouette_vals)
    y_lower += len(cluster_silhouette_vals)

plt.title('Silhouette Plot for the Clusters')
plt.xlabel('Silhouette Coefficient Values')
plt.ylabel('Cluster')
plt.axvline(x=silhouette_score(normalized_data, clusters), color="red", linestyle="--")
plt.show()

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
# Out:
# WARNING:tensorflow:From C:\Users\mdjqp\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\mdjqp\AppData\Local\Temp\ipykernel_19824\292850708.py:2: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.

# %%
import umap.umap_ as umap
import matplotlib.pyplot as plt

# Reducir la dimensionalidad a 2D usando UMAP
umap_reducer = umap.UMAP(random_state=42)
umap_components = umap_reducer.fit_transform(normalized_data)

# Graficar los clusters usando UMAP
plt.figure(figsize=(10, 6))
scatter = plt.scatter(umap_components[:, 0], umap_components[:, 1], c=clusters, cmap='viridis')
plt.title('Clusters Visualized using UMAP')
plt.xlabel('UMAP Component 1')
plt.ylabel('UMAP Component 2')
plt.colorbar(scatter, label='Cluster')
plt.grid(True)
plt.show()
# Out:
# C:\Users\mdjqp\AppData\Roaming\Python\Python311\site-packages\umap\umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
from sklearn.manifold import MDS

# Reducir la dimensionalidad a 2D usando MDS
mds = MDS(n_components=2, random_state=42)
mds_components = mds.fit_transform(normalized_data)

# Graficar los clusters usando MDS
plt.figure(figsize=(10, 6))
scatter = plt.scatter(mds_components[:, 0], mds_components[:, 1], c=clusters, cmap='viridis')
plt.title('Clusters Visualized using MDS')
plt.xlabel('MDS Component 1')
plt.ylabel('MDS Component 2')
plt.colorbar(scatter, label='Cluster')
plt.grid(True)
plt.show()
# Out:
# C:\Users\mdjqp\AppData\Roaming\Python\Python311\site-packages\sklearn\manifold\_mds.py:298: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(

# %%
from sklearn.manifold import TSNE

# Reducir la dimensionalidad a 2D usando t-SNE
tsne = TSNE(n_components=2, random_state=42)
tsne_components = tsne.fit_transform(normalized_data)

# Graficar los clusters usando t-SNE
plt.figure(figsize=(10, 6))
scatter = plt.scatter(tsne_components[:, 0], tsne_components[:, 1], c=clusters, cmap='viridis')
plt.title('Clusters Visualized using t-SNE')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.colorbar(scatter, label='Cluster')
plt.grid(True)
plt.show()
